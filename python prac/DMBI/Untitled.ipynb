# %%
from numpy import genfromtxt

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = genfromtxt('population_by_country_2020.csv' ,delimiter=',')

# %%
plt.plot(data)

# %%
country =df['Country']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-25dc607a527e> in <module>
# ----> 1 country =df['Country']
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv('population_by_country_2020.csv')

# %%
country=df['Country']

# %%
population=df['Population']

# %%
plt.plot(country, population)

# %%
colours = ["skyblue", "blue", "red", "yellow", "green","orange","pink","brown","grey","dark orange"]

# %%
plt.figure(figsize=(7,7))

# %%
plt.pie(population, labels=country, autopct='%1.1f%%', colors=colours)
central_circle = plt.Circle((0, 0), 0.4, color='white')

# %%
fig = plt.gcf()

# %%
fig.gca().add_artist(central_circle)

# %%
plt.rc(size=12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-0cd932b52c5f> in <module>
# ----> 1 plt.rc(size=12)
#
# TypeError: rc() missing 1 required positional argument: 'group'

# %%
plt.rc('font', size=12)

# %%
plt.show()

# %%
plt.plot()
# Out:
# []

# %%
plt.plot(central_circle)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-1f7957953351> in <module>
# ----> 1 plt.plot(central_circle)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2822 @_copy_docstring_and_deprecators(Axes.plot)
#    2823 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2824     return gca().plot(
#    2825         *args, scalex=scalex, scaley=scaley,
#    2826         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
# -> 1745             self.add_line(line)
#    1746         self._request_autoscale_view(scalex=scalex, scaley=scaley)
# ...

# %%
plt.pie(population, labels=country, autopct='%1.1f%%', colors=colours)
central_circle = plt.Circle((0, 0), 0.4, color='white')
donut=plt.gcf()
donut.gca().add_artist(circle)
plt.axis('equal')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-285f72e2af0a> in <module>
#       2 central_circle = plt.Circle((0, 0), 0.4, color='white')
#       3 donut=plt.gcf()
# ----> 4 donut.gca().add_artist(circle)
#       5 plt.axis('equal')
#       6 plt.tight_layout()
#
# NameError: name 'circle' is not defined

# %%
plt.pie(population, labels=country, autopct='%1.1f%%', colors=colours)
circle = plt.Circle((0, 0), 0.4, color='white')
donut=plt.gcf()
donut.gca().add_artist(circle)
plt.axis('equal')
plt.tight_layout()

# %%
plt.pie(population, labels=country, autopct='%1.1f%%', colors=colours)
central_circle = plt.Circle((0, 0), 0.65, color='white')
donut=plt.gcf()
donut.gca().add_artist(circle)
plt.axis('equal')
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-f5b6164961c6> in <module>
#       2 central_circle = plt.Circle((0, 0), 0.65, color='white')
#       3 donut=plt.gcf()
# ----> 4 donut.gca().add_artist(circle)
#       5 plt.axis('equal')
#       6 plt.tight_layout()
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_artist(self, a)
#    1894         ``ax.transData``.
#    1895         """
# -> 1896         a.axes = self
#    1897         self.artists.append(a)
#    1898         a._remove_method = self.artists.remove
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in axes(self, new_axes)
#     196         if (new_axes is not None and self._axes is not None
#     197                 and new_axes != self._axes):
# --> 198             raise ValueError("Can not reset the axes.  You are probably "
# ...

# %%
plt.pie(population, labels=country, autopct='%1.1f%%', colors=colours)
circle = plt.Circle((0, 0), 0.7, color='white')
donut=plt.gcf()
donut.gca().add_artist(circle)
plt.axis('equal')
plt.tight_layout()

# %%
data=[[1,2,3],[4,5,6],[7,8,9]]

# %%
import numpy as np
import matplotlib.pyplot as plt
data = [[30, 25, 50, 20],
[40, 23, 51, 17],
[35, 22, 45, 19]]
X = np.arange(4)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(X + 0.00, data[0], color = 'b', width = 0.25)
ax.bar(X + 0.25, data[1], color = 'g', width = 0.25)
ax.bar(X + 0.50, data[2], color = 'r', width = 0.25)
# Out:
# <BarContainer object of 4 artists>

# %%
import numpy as np 

import matplotlib.pyplot as plt 
 
# set width of bar 

barWidth = 0.25

fig = plt.subplots(figsize =(12, 8)) 
 
# set height of bar 
population=df['Population']
yearly_change=df['Yearly Change']
net_change=df['Net Change']


 
# Set position of bar on X axis 

br1 = np.arange(len(population)) 

br2 = [x + barWidth for x in br1] 

br3 = [x + barWidth for x in br2] 
 
# Make the plot

plt.bar(br1, population, color ='r', width = barWidth, 

        edgecolor ='grey', label ='Population') 

plt.bar(br2, yearly_change, color ='g', width = barWidth, 

        edgecolor ='grey', label ='Yearly Change') 

plt.bar(br3, net_change, color ='b', width = barWidth, 

        edgecolor ='grey', label ='Net Change') 
 
# Adding Xticks 

plt.xlabel('Countries', fontweight ='bold', fontsize = 15) 



plt.xticks([r + barWidth for r in range(len(population))], 

        ['China', 'India', 'United States', 'Indonesia', 'Pakistan','Brazil','Nigeria','Bangladesh','Russia'])
 
plt.legend()
plt.show()

# %%
import numpy as np 

import matplotlib.pyplot as plt 
 
# set width of bar 

barWidth = 0.25

fig = plt.subplots(figsize =(12, 8)) 
 
# set height of bar 
population=df['Population']
yearly_change=df['Yearly Change']
land_area=df['Land Area']


 
# Set position of bar on X axis 

br1 = np.arange(len(population)) 

br2 = [x + barWidth for x in br1] 

br3 = [x + barWidth for x in br2] 
 
# Make the plot

plt.bar(br1, population, color ='r', width = barWidth, 

        edgecolor ='grey', label ='Population') 

plt.bar(br2, yearly_change, color ='g', width = barWidth, 

        edgecolor ='grey', label ='Yearly Change') 

plt.bar(br3, land_area, color ='b', width = barWidth, 

        edgecolor ='grey', label ='Land Area') 
 
# Adding Xticks 

plt.xlabel('Countries', fontweight ='bold', fontsize = 15) 



plt.xticks([r + barWidth for r in range(len(population))], 

        ['China', 'India', 'United States', 'Indonesia', 'Pakistan','Brazil','Nigeria','Bangladesh','Russia'])
 
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Land Area'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-cad9870d83bb> in <module>
#      12 population=df['Population']
# ...

# %%
import numpy as np 

import matplotlib.pyplot as plt 
 
# set width of bar 

barWidth = 0.25

fig = plt.subplots(figsize =(12, 8)) 
 
# set height of bar 
population=df['Population']
yearly_change=df['Yearly Change']
land_area=df['Land Area']


 
# Set position of bar on X axis 

br1 = np.arange(len(population)) 

br2 = [x + barWidth for x in br1] 

br3 = [x + barWidth for x in br2] 
 
# Make the plot

plt.bar(br1, population, color ='r', width = barWidth, 

        edgecolor ='grey', label ='Population') 

plt.bar(br2, yearly_change, color ='g', width = barWidth, 

        edgecolor ='grey', label ='Yearly Change') 

plt.bar(br3, land_area,coloridth = barWidth, 

        edgecolor ='grey', label ='Land Area')
 
# Adding Xticks 

plt.xlabel('Countries', fontweight ='bold', fontsize = 15) 



plt.xticks([r + barWidth for r in range(len(population))], 

        ['China', 'India', 'United States', 'Indonesia', 'Pakistan','Brazil','Nigeria','Bangladesh','Russia'])
 
plt.legend()
plt.show()
# Out:
#   File "<ipython-input-29-ee0ff620ea41>", line 36
#     plt.bar(br3, land_area'b', width = barWidth,
#                           ^
# SyntaxError: invalid syntax

# %%
import numpy as np 

import matplotlib.pyplot as plt 
 
# set width of bar 

barWidth = 0.25

fig = plt.subplots(figsize =(12, 8)) 
 
# set height of bar 
population=df['Population']
yearly_change=df['Yearly Change']
land_area=df['Land Area']


 
# Set position of bar on X axis 

br1 = np.arange(len(population)) 

br2 = [x + barWidth for x in br1] 

br3 = [x + barWidth for x in br2] 
 
# Make the plot

plt.bar(br1, population, color ='r', width = barWidth, 

        edgecolor ='grey', label ='Population') 

plt.bar(br2, yearly_change, color ='g', width = barWidth, 

        edgecolor ='grey', label ='Yearly Change') 

plt.bar(br3, land_area, color ='b', width = barWidth, 

        edgecolor ='grey', label ='Land Area') 
 
# Adding Xticks 

plt.xlabel('Countries', fontweight ='bold', fontsize = 15) 



plt.xticks([r + barWidth for r in range(len(population))], 

        ['China', 'India', 'United States', 'Indonesia', 'Pakistan','Brazil','Nigeria','Bangladesh','Russia'])
 
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Land Area'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-09b93417feb2> in <module>
#      12 population=df['Population']
# ...

# %%
import numpy as np 

import matplotlib.pyplot as plt 
 
# set width of bar 

barWidth = 0.25

fig = plt.subplots(figsize =(12, 8)) 
 
# set height of bar 
population=df['Population']
yearly_change=df['Yearly Change']
net_change=df['Net Change']


 
# Set position of bar on X axis 

br1 = np.arange(len(population)) 

br2 = [x + barWidth for x in br1] 

br3 = [x + barWidth for x in br2] 
 
# Make the plot

plt.bar(br1, population, color ='r', width = barWidth, 

        edgecolor ='grey', label ='Population') 

plt.bar(br2, yearly_change, color ='g', width = barWidth, 

        edgecolor ='grey', label ='Yearly Change') 

plt.bar(br3, net_change, color ='b', width = barWidth, 

        edgecolor ='grey', label ='Net Change') 
 
# Adding Xticks 

plt.xlabel('Countries', fontweight ='bold', fontsize = 15) 



plt.xticks([r + barWidth for r in range(len(population))], 

        ['China', 'India', 'United States', 'Indonesia', 'Pakistan','Brazil','Nigeria','Bangladesh','Russia'])
 
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

population=df['Population']

net_change=df['Net Change']
width =0.3
plt.bar(np.arange(len(population)),population , width=width, label ='Population')
#plt.bar(np.arange(len(yearly_change))+ width, yearly_change, width=width)
plt.bar(np.arange(len(net_change))+ width, net_change, width=width, label ='Net Change')
plt.legend()
plt.show()

# %%
import pandas as pd

from matplotlib import pyplot as plt
 
# Read CSV into pandas

data = pd.read_csv('population_by_country_2020.csv')


df = pd.DataFrame(data)
 

population=df['Population']

country=df['Country']
 
# Figure Size

fig, ax = plt.subplots(figsize =(16, 9))
 
# Horizontal Bar Plot
ax.barh(country, population)
 
# Remove axes splines

for s in ['top', 'bottom', 'left', 'right']:

    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks

ax.xaxis.set_ticks_position('none')

ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels

ax.xaxis.set_tick_params(pad = 5)

ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines

ax.grid(b = True, color ='grey',

        linestyle ='-.', linewidth = 0.5,

        alpha = 0.2)
 
# Show top values 
ax.invert_yaxis()
 
# Add annotation to bars

for i in ax.patches:

    plt.text(i.get_width()+0.2, i.get_y()+0.5, 

             str(round((i.get_width()), 2)),

             fontsize = 10, fontweight ='bold',

             color ='grey')
 
# Add Plot Title


 
# Add Text watermark


 
# Show Plot
plt.show()
